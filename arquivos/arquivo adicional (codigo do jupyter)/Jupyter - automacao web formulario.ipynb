# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import pandas as pd
import time
#### pegar dados ##########

df_produtos = pd.read_csv('produtos.csv')

#### automação ###########
servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

    # Usar o arquivo Formulario.html caso o site esteja off
navegador.get("https://dlp.hashtagtreinamentos.com/python/intensivao/tabela")
time.sleep(1)

formularios = navegador.find_elements(By.CLASS_NAME, 'form-campo')

for item, linha in df_produtos.iterrows():
    for i, campo in enumerate(formularios):
        dados = linha[i]
        dados = str(dados)
        campo.find_element(By.TAG_NAME, 'input').clear()  # Limpa o campo antes de preenchê-lo
        campo.find_element(By.TAG_NAME, 'input').send_keys(str(dados))
        campo.find_element(By.XPATH, '//*[@id="pgtpy-botao"]').click()
        campo.find_element(By.XPATH, '//*[@id="pgtpy-botao"]').click()
        if dados.lower() == 'nan':
            campo.find_element(By.XPATH, '//*[@id="obs"]').clear()
# Out:
#          codigo       marca        tipo  categoria  preco_unitario  custo  \
# 0    MOLO000251    Logitech       Mouse          1           25.95    6.5
# 1    MOLO000192    Logitech       Mouse          2           19.95    5.0
# 2    CAHA000251     Hashtag      Camisa          1           25.00   11.0
# 3    CAHA000252     Hashtag      Camisa          2           25.00   11.0
# 4    MOMU000111  Multilaser       Mouse          1           11.99    3.4
# ..          ...         ...         ...        ...             ...    ...
# 288  ACAP000192       Apple  Acessorios          2           19.00    3.8
# 289  ACSA0009.3     Samsung  Acessorios          3            9.55    2.1
# 290  CEMO000271    Motorola     Celular          1          279.00   72.5
# 291  FOMO000152    Motorola        Fone          2          150.00   33.0
# 292  CEMO000223    Motorola     Celular          3          229.00   55.0
#
#                   obs
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3    Conferir estoque
# 4                 NaN
# ..                ...
# 288               NaN
# 289               NaN
# 290               NaN
# 291               NaN
# 292               NaN
#
# [293 rows x 7 columns]
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_12188\3640145829.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dados = linha[i]
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[53], line 31
#      29 campo.find_element(By.TAG_NAME, 'input').clear()  # Limpa o campo antes de preenchê-lo
#      30 campo.find_element(By.TAG_NAME, 'input').send_keys(str(dados))
# ---> 31 campo.find_element(By.XPATH, '//*[@id="pgtpy-botao"]').click()
#      32 campo.find_element(By.XPATH, '//*[@id="pgtpy-botao"]').click()
#      33 if dados.lower() == 'nan':
#
# File c:\Users\Windows 10\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:94, in WebElement.click(self)
#      92 def click(self) -> None:
#      93     """Clicks the element."""
# ---> 94     self._execute(Command.CLICK_ELEMENT)
#
# File c:\Users\Windows 10\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File c:\Users\Windows 10\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File c:\Users\Windows 10\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element <button type="submit" id="pgtpy-botao">...</button> is not clickable at point (388, 430). Other element would receive the click: <td>...</td>
#   (Session info: chrome=129.0.6668.101)
# Stacktrace:
# 	GetHandleVerifier [0x00E95523+24195]
# 	(No symbol) [0x00E2AA04]
# 	(No symbol) [0x00D22093]
# 	(No symbol) [0x00D6CE37]
# 	(No symbol) [0x00D6B239]
# 	(No symbol) [0x00D6911B]
# 	(No symbol) [0x00D68724]
# 	(No symbol) [0x00D5D4FD]
# 	(No symbol) [0x00D8AB3C]
# 	(No symbol) [0x00D5CFB4]
# 	(No symbol) [0x00D8ADD4]
# 	(No symbol) [0x00DA5280]
# 	(No symbol) [0x00D8A8D6]
# 	(No symbol) [0x00D5BA27]
# 	(No symbol) [0x00D5C43D]
# 	GetHandleVerifier [0x0115CE13+2938739]
# 	GetHandleVerifier [0x011AEC69+3274185]
# 	GetHandleVerifier [0x00F209C2+594722]
# 	GetHandleVerifier [0x00F27EDC+624700]
# 	(No symbol) [0x00E337CD]
# 	(No symbol) [0x00E30528]
# 	(No symbol) [0x00E306C5]
# 	(No symbol) [0x00E22CA6]
# 	BaseThreadInitThunk [0x76CB7BA9+25]
# 	RtlInitializeExceptionChain [0x7705C11B+107]
# 	RtlClearBits [0x7705C09F+191]
